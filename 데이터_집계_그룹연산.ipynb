# %% [markdown]
# <a href="https://colab.research.google.com/github/jennyohyj/jennyohyj.github.io/blob/pandas%2Fnumpy-practice/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A7%91%EA%B3%84_%EA%B7%B8%EB%A3%B9%EC%97%B0%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame([[1,1.2,np.nan],
                [2.4,5.5,4.2],
                [np.nan,np.nan,np.nan],
                [0.44,-3.1,-4.1]],
                index=[1,2,3,4],
                columns=['A','B','C'])
df
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1

# %%
df.head(2)
# Out:
#      A    B    C
# 1  1.0  1.2  NaN
# 2  2.4  5.5  4.2

# %%
df.tail(2)
# Out:
#       A    B    C
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1

# %%
df.describe()
# Out:
#               A     B         C
# count  3.000000  3.00  2.000000
# mean   1.280000  1.20  0.050000
# std    1.009554  4.30  5.868986
# min    0.440000 -3.10 -4.100000
# 25%    0.720000 -0.95 -2.025000
# 50%    1.000000  1.20  0.050000
# 75%    1.700000  3.35  2.125000
# max    2.400000  5.50  4.200000

# %%
print(df)
print(np.argmin(df),np.argmax(df))
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# 2 2

# %%
print(df)
print(df.idxmin())
print(df.idxmax())
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    4
# B    4
# C    4
# dtype: int64
# A    2
# B    2
# C    2
# dtype: int64

# %%
print(df)
print(df.std())
print(df.var())
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    1.009554
# B    4.300000
# C    5.868986
# dtype: float64
# A     1.0192
# B    18.4900
# C    34.4450
# dtype: float64

# %%
print(df)
print(df.skew())
print(df.kurt())
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    1.15207
# B    0.00000
# C        NaN
# dtype: float64
# A   NaN
# B   NaN
# C   NaN
# dtype: float64

# %%
print(df)
print(df.sum())
print(df.cumsum())
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A    3.84
# B    3.60
# C    0.10
# dtype: float64
#       A    B    C
# 1  1.00  1.2  NaN
# 2  3.40  6.7  4.2
# 3   NaN  NaN  NaN
# 4  3.84  3.6  0.1

# %%
print(df)
print(df.prod())
print(df.cumprod())
# Out:
#       A    B    C
# 1  1.00  1.2  NaN
# 2  2.40  5.5  4.2
# 3   NaN  NaN  NaN
# 4  0.44 -3.1 -4.1
# A     1.056
# B   -20.460
# C   -17.220
# dtype: float64
#        A      B      C
# 1  1.000   1.20    NaN
# 2  2.400   6.60   4.20
# 3    NaN    NaN    NaN
# 4  1.056 -20.46 -17.22

# %%
df.diff() ##차 구하기
# Out:
#      A    B   C
# 1  NaN  NaN NaN
# 2  1.4  4.3 NaN
# 3  NaN  NaN NaN
# 4  NaN  NaN NaN

# %%
df.quantile()
# Out:
# A    1.00
# B    1.20
# C    0.05
# Name: 0.5, dtype: float64

# %%
df.pct_change()
# Out:
#           A         B        C
# 1       NaN       NaN      NaN
# 2  1.400000  3.583333      NaN
# 3  0.000000  0.000000  0.00000
# 4 -0.816667 -1.563636 -1.97619

# %%
df.corr()
# Out:
#           A         B    C
# A  1.000000  0.970725  1.0
# B  0.970725  1.000000  1.0
# C  1.000000  1.000000  1.0

# %%
df.corrwith(df.B)
# Out:
# A    0.970725
# B    1.000000
# C    1.000000
# dtype: float64

# %%
df.cov() ##공분산 계산
# Out:
#         A       B       C
# A  1.0192   4.214   8.134
# B  4.2140  18.490  35.690
# C  8.1340  35.690  34.445

# %%
df['B'].unique()
# Out:
# array([ 1.2,  5.5,  nan, -3.1])

# %%
df['A'].value_counts()
# Out:
# 1.00    1
# 2.40    1
# 0.44    1
# Name: A, dtype: int64

# %%
##groupby 연산

# %%
df=pd.DataFrame({'c1':['a','a','b','b','c','d','b'],
                 'c2':['A','B','B','A','D','C','C'],
                 'c3':np.random.randint(7),
                 'c4':np.random.random(7)})
df
# Out:
#   c1 c2  c3        c4
# 0  a  A   3  0.731618
# 1  a  B   3  0.559293
# 2  b  B   3  0.226143
# 3  b  A   3  0.255300
# 4  c  D   3  0.438261
# 5  d  C   3  0.634778
# 6  b  C   3  0.954565

# %%
df.dtypes
# Out:
# c1     object
# c2     object
# c3      int64
# c4    float64
# dtype: object

# %%
df['c3'].groupby(df['c1']).mean()
# Out:
# c1
# a    3.0
# b    3.0
# c    3.0
# d    3.0
# Name: c3, dtype: float64

# %%
df['c4'].groupby(df['c2']).std()
# Out:
# c2
# A    0.336808
# B    0.235573
# C    0.226124
# D         NaN
# Name: c4, dtype: float64

# %%
df['c4'].groupby([df['c1'],df['c2']]).mean()
# Out:
# c1  c2
# a   A     0.731618
#     B     0.559293
# b   A     0.255300
#     B     0.226143
#     C     0.954565
# c   D     0.438261
# d   C     0.634778
# Name: c4, dtype: float64

# %%
df['c4'].groupby([df['c1'],df['c2']]).mean().unstack()
# Out:
# c2         A         B         C         D
# c1
# a   0.731618  0.559293       NaN       NaN
# b   0.255300  0.226143  0.954565       NaN
# c        NaN       NaN       NaN  0.438261
# d        NaN       NaN  0.634778       NaN

# %%
df.groupby('c1').mean()
# Out:
#      c3        c4
# c1
# a   3.0  0.645456
# b   3.0  0.478669
# c   3.0  0.438261
# d   3.0  0.634778

# %%
df.groupby(['c1','c2']).mean()
# Out:
#         c3        c4
# c1 c2
# a  A   3.0  0.731618
#    B   3.0  0.559293
# b  A   3.0  0.255300
#    B   3.0  0.226143
#    C   3.0  0.954565
# c  D   3.0  0.438261
# d  C   3.0  0.634778

# %%
df.groupby(['c1','c2']).size()
# Out:
# c1  c2
# a   A     1
#     B     1
# b   A     1
#     B     1
#     C     1
# c   D     1
# d   C     1
# dtype: int64

# %%
for c1, group in df.groupby('c1'):
  print(c1)
  print(group)
# Out:
# a
#   c1 c2  c3        c4
# 0  a  A   3  0.731618
# 1  a  B   3  0.559293
# b
#   c1 c2  c3        c4
# 2  b  B   3  0.226143
# 3  b  A   3  0.255300
# 6  b  C   3  0.954565
# c
#   c1 c2  c3        c4
# 4  c  D   3  0.438261
# d
#   c1 c2  c3        c4
# 5  d  C   3  0.634778

# %%
for (c1,c2), group in df.groupby(['c1','c2']):
  print((c1,c2))
  print(group)
# Out:
# ('a', 'A')
#   c1 c2  c3        c4
# 0  a  A   3  0.731618
# ('a', 'B')
#   c1 c2  c3        c4
# 1  a  B   3  0.559293
# ('b', 'A')
#   c1 c2  c3      c4
# 3  b  A   3  0.2553
# ('b', 'B')
#   c1 c2  c3        c4
# 2  b  B   3  0.226143
# ('b', 'C')
#   c1 c2  c3        c4
# 6  b  C   3  0.954565
# ('c', 'D')
#   c1 c2  c3        c4
# 4  c  D   3  0.438261
# ('d', 'C')
#   c1 c2  c3        c4
# 5  d  C   3  0.634778

# %%
df.groupby(['c1','c2'])[['c4']].mean()
# Out:
#              c4
# c1 c2
# a  A   0.731618
#    B   0.559293
# b  A   0.255300
#    B   0.226143
#    C   0.954565
# c  D   0.438261
# d  C   0.634778

# %%
df.groupby('c1')['c3'].quantile()
# Out:
# c1
# a    3.0
# b    3.0
# c    3.0
# d    3.0
# Name: c3, dtype: float64

# %%
df.groupby('c1')['c3'].count()
# Out:
# c1
# a    2
# b    3
# c    1
# d    1
# Name: c3, dtype: int64

# %%
df.groupby('c1')['c4'].median()
# Out:
# c1
# a    0.645456
# b    0.255300
# c    0.438261
# d    0.634778
# Name: c4, dtype: float64

# %%
df.groupby(['c1','c2'])['c4'].agg(['mean','min','max'])
# Out:
#            mean       min       max
# c1 c2
# a  A   0.731618  0.731618  0.731618
#    B   0.559293  0.559293  0.559293
# b  A   0.255300  0.255300  0.255300
#    B   0.226143  0.226143  0.226143
#    C   0.954565  0.954565  0.954565
# c  D   0.438261  0.438261  0.438261
# d  C   0.634778  0.634778  0.634778

# %%
df.groupby(['c1','c2'],as_index=False)['c4'].mean()
# Out:
#   c1 c2        c4
# 0  a  A  0.731618
# 1  a  B  0.559293
# 2  b  A  0.255300
# 3  b  B  0.226143
# 4  b  C  0.954565
# 5  c  D  0.438261
# 6  d  C  0.634778

# %%
df.groupby(['c1','c2'],group_keys=False)['c4'].mean()
# Out:
# c1  c2
# a   A     0.731618
#     B     0.559293
# b   A     0.255300
#     B     0.226143
#     C     0.954565
# c   D     0.438261
# d   C     0.634778
# Name: c4, dtype: float64

# %%
def top(df,n=3,column='c1'):
  return df.sort_values(by=column)[-n:]
top(df,n=5)
# Out:
#   c1 c2  c3        c4
# 2  b  B   3  0.226143
# 3  b  A   3  0.255300
# 6  b  C   3  0.954565
# 4  c  D   3  0.438261
# 5  d  C   3  0.634778

# %%
df.groupby('c1').apply(top)
# Out:
#      c1 c2  c3        c4
# c1
# a  0  a  A   3  0.731618
#    1  a  B   3  0.559293
# b  2  b  B   3  0.226143
#    3  b  A   3  0.255300
#    6  b  C   3  0.954565
# c  4  c  D   3  0.438261
# d  5  d  C   3  0.634778

# %%
df.pivot_table(['c3','c4'],
               index=['c1'],
               columns=['c2'])
# Out:
#      c3                       c4
# c2    A    B    C    D         A         B         C         D
# c1
# a   3.0  3.0  NaN  NaN  0.731618  0.559293       NaN       NaN
# b   3.0  3.0  3.0  NaN  0.255300  0.226143  0.954565       NaN
# c   NaN  NaN  NaN  3.0       NaN       NaN       NaN  0.438261
# d   NaN  NaN  3.0  NaN       NaN       NaN  0.634778       NaN

# %%
df.pivot_table(['c3','c4'],
               index=['c1'],
               columns=['c2'],
               margins=True)
# Out:
#       c3                            c4
# c2     A    B    C    D  All         A         B         C         D       All
# c1
# a    3.0  3.0  NaN  NaN  3.0  0.731618  0.559293       NaN       NaN  0.645456
# b    3.0  3.0  3.0  NaN  3.0  0.255300  0.226143  0.954565       NaN  0.478669
# c    NaN  NaN  NaN  3.0  3.0       NaN       NaN       NaN  0.438261  0.438261
# d    NaN  NaN  3.0  NaN  3.0       NaN       NaN  0.634778       NaN  0.634778
# All  3.0  3.0  3.0  3.0  3.0  0.493459  0.392718  0.794672  0.438261  0.542851

# %%
df.pivot_table(['c3','c4'],
               index=['c1'],
               columns=['c2'],
               margins=True,
               aggfunc=sum)
# Out:
#       c3                           c4
# c2     A    B    C    D All         A         B         C         D       All
# c1
# a    3.0  3.0  NaN  NaN   6  0.731618  0.559293       NaN       NaN  1.290911
# b    3.0  3.0  3.0  NaN   9  0.255300  0.226143  0.954565       NaN  1.436008
# c    NaN  NaN  NaN  3.0   3       NaN       NaN       NaN  0.438261  0.438261
# d    NaN  NaN  3.0  NaN   3       NaN       NaN  0.634778       NaN  0.634778
# All  6.0  6.0  6.0  3.0  21  0.986918  0.785436  1.589344  0.438261  3.799959

# %%
df.pivot_table(['c3','c4'],
               index=['c1'],
               columns=['c2'],
               margins=True,
               aggfunc=sum,
               fill_value=0)
# Out:
#     c3                     c4
# c2   A  B  C  D All         A         B         C         D       All
# c1
# a    3  3  0  0   6  0.731618  0.559293  0.000000  0.000000  1.290911
# b    3  3  3  0   9  0.255300  0.226143  0.954565  0.000000  1.436008
# c    0  0  0  3   3  0.000000  0.000000  0.000000  0.438261  0.438261
# d    0  0  3  0   3  0.000000  0.000000  0.634778  0.000000  0.634778
# All  6  6  6  3  21  0.986918  0.785436  1.589344  0.438261  3.799959

# %%
pd.crosstab(df.c1,df.c2)
# Out:
# c2  A  B  C  D
# c1
# a   1  1  0  0
# b   1  1  1  0
# c   0  0  0  1
# d   0  0  1  0

# %%
pd.crosstab(df.c1,df.c2,values=df.c3,aggfunc=sum,margins=True)
# Out:
# c2     A    B    C    D  All
# c1
# a    3.0  3.0  NaN  NaN    6
# b    3.0  3.0  3.0  NaN    9
# c    NaN  NaN  NaN  3.0    3
# d    NaN  NaN  3.0  NaN    3
# All  6.0  6.0  6.0  3.0   21

# %%
##범주형 데이터

# %%
s=pd.Series(['c1','c2','c1','c2','c1']*2)
s
# Out:
# 0    c1
# 1    c2
# 2    c1
# 3    c2
# 4    c1
# 5    c1
# 6    c2
# 7    c1
# 8    c2
# 9    c1
# dtype: object

# %%
pd.unique(s)
# Out:
# array(['c1', 'c2'], dtype=object)

# %%
pd.value_counts(s)
# Out:
# c1    6
# c2    4
# dtype: int64

# %%
code=pd.Series([0,1,0,1,0]*2)
code
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    1
# 7    0
# 8    1
# 9    0
# dtype: int64

# %%
d=pd.Series(['c1','c2'])
d
# Out:
# 0    c1
# 1    c2
# dtype: object

# %%
d.take(code)
# Out:
# 0    c1
# 1    c2
# 0    c1
# 1    c2
# 0    c1
# 0    c1
# 1    c2
# 0    c1
# 1    c2
# 0    c1
# dtype: object

# %%
df=pd.DataFrame({'id':np.arange(len(s)),
                'c':s,
                'v':np.random.randint(1000,5000,size=len(s))})
df
# Out:
#    id   c     v
# 0   0  c1  1232
# 1   1  c2  4289
# 2   2  c1  3971
# 3   3  c2  1787
# 4   4  c1  1622
# 5   5  c1  4248
# 6   6  c2  2027
# 7   7  c1  4961
# 8   8  c2  2823
# 9   9  c1  1075

# %%
c=df['c'].astype('category')
c
# Out:
# 0    c1
# 1    c2
# 2    c1
# 3    c2
# 4    c1
# 5    c1
# 6    c2
# 7    c1
# 8    c2
# 9    c1
# Name: c, dtype: category
# Categories (2, object): ['c1', 'c2']

# %%
c.values
# Out:
# ['c1', 'c2', 'c1', 'c2', 'c1', 'c1', 'c2', 'c1', 'c2', 'c1']
# Categories (2, object): ['c1', 'c2']

# %%
c.values.categories
# Out:
# Index(['c1', 'c2'], dtype='object')

# %%
c.values.codes
# Out:
# array([0, 1, 0, 1, 0, 0, 1, 0, 1, 0], dtype=int8)

# %%
df['c']=c
df.c
# Out:
# 0    c1
# 1    c2
# 2    c1
# 3    c2
# 4    c1
# 5    c1
# 6    c2
# 7    c1
# 8    c2
# 9    c1
# Name: c, dtype: category
# Categories (2, object): ['c1', 'c2']

# %%
c=pd.Categorical(['c1','c2','c3','c1','c2'])
c
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1', 'c2', 'c3']

# %%
categories=['c1','c2','c3']
codes=[0,1,2,0,1]
c=pd.Categorical.from_codes(codes,categories)
c
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1', 'c2', 'c3']

# %%
pd.Categorical.from_codes(codes,categories,ordered=True)
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1' < 'c2' < 'c3']

# %%
c.as_ordered()
# Out:
# ['c1', 'c2', 'c3', 'c1', 'c2']
# Categories (3, object): ['c1' < 'c2' < 'c3']

# %%
c.codes
# Out:
# array([0, 1, 2, 0, 1], dtype=int8)

# %%
c.categories
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')

# %%
c=c.set_categories(['c1','c2','c3','c4','c5'])
c.categories
# Out:
# Index(['c1', 'c2', 'c3', 'c4', 'c5'], dtype='object')

# %%
c.value_counts()
# Out:
# c1    2
# c2    2
# c3    1
# c4    0
# c5    0
# dtype: int64

# %%
c[c.isin(['c1','c3'])]
# Out:
# ['c1', 'c3', 'c1']
# Categories (5, object): ['c1', 'c2', 'c3', 'c4', 'c5']

# %%
c=c.remove_unused_categories()

# %%
c.categories
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')
